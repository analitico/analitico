# %% [markdown]
# ## Hello world
#
# Say hello

# %%
# Prepare your data

# %%
# This method will be called on your serverless endpoint
def handle(event, **kwargs):
    # Say hello
    return "Hello world"
